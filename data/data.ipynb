# %%
import pandas as pd

# baca file csv, kalo NAMA FILE BEDA ganti aja jadi sesuai nama filenya, contoh: '<namaFile>.csv'
df = pd.read_csv('data brw.csv',
                 on_bad_lines='skip', delimiter=';')

df = df.dropna(how="all")
# buat nampilin doang

print(df)
# df.info()
# Out:
#             Timestamp\n                   Nama Lengkap  \
# 0     11 7 2022 0:05:47      Muhammad Hilmy Abdul Aziz
# 1    11 7 2022 18:16:26                 Soros Febriano
# 2    11 7 2022 21:19:46       Gyanamurti Adhikara Bano
# 3    11 8 2022 18:40:08                Aaron Mario Lin
# 4    11 8 2022 18:47:46          Adrial Natanael Liong
# ..                  ...                            ...
# 58   11 9 2022 23:47:03  Fariska Fedira Ardhanariswari
# 59   11 10 2022 0:25:53          Melvara Zafirah Ramsi
# 60  11 10 2022 19:51:43           Eryanda Arian Ro'uuf
# 61  11 13 2022 15:40:39   Muhammad Faishal Adly Nelwan
# 62  11 18 2022 15:49:50               Chelsea Angelica
#
#                    Nama Panggilan Tanggal Lahir  \
# 0                           Hilmy    30 09 2005
# 1                           Soros    21 02 2004
# 2                            Gyan     9 10 2003
# 3                           Aaron    29 03 2004
# 4                          Adrial    15 09 2004
# ...

# %%
# ngilangin kolom timestamp sama rename semua kolom biar jelas
df.drop('Timestamp\n', axis=1, inplace=True)
df.rename(columns={'Media Sosial (Line & Instagram)\nContoh:\nLine: https://line.me/ti/p/Q1hqgliRYf\nInstagram: instagram.com/csui.2022': 'MedSos', 'Deskripsi Singkat\n(Fun Fact atau kalimat bebas yang deskripsiin kamu)': 'Deskripsi Singkat', 'Interest\n(Contoh: Web Dev, UI/UX, Marvel, Valorant.)': 'Interest', 'Pesan untuk CSUI 22\n(Pesan/harapan kamu kedepannya untuk CSUI 22)': 'Pesan buat CSUI22'}, inplace=True)

# buat nampilin doang
df.head()
# Out:
#                 Nama Lengkap Nama Panggilan Tanggal Lahir  \
# 0  Muhammad Hilmy Abdul Aziz          Hilmy    30 09 2005
# 1             Soros Febriano          Soros    21 02 2004
# 2   Gyanamurti Adhikara Bano           Gyan     9 10 2003
# 3            Aaron Mario Lin          Aaron    29 03 2004
# 4      Adrial Natanael Liong         Adrial    15 09 2004
#
#                                          Foto (.jpg)  \
# 0  https://drive.google.com/open?id=1BmHDtiG2j-4Q...
# 1  https://drive.google.com/open?id=1P2oIp-DLe3tr...
# 2  https://drive.google.com/open?id=1lEFtpZUOTH91...
# 3  https://drive.google.com/open?id=1dmES9XX8qVh-...
# 4  https://drive.google.com/open?id=1sgZXjZqbWkC8...
#
#                                               MedSos  \
# 0  Line:  https://line.me/ti/p/eKSTrugSag Instagr...
# 1          https://www.instagram.com/soros_febriano/
# 2  Line: gyanbano09 Instagram: instagram.com/gyan...
# 3  Line: http://line.me/ti/p/aaronmlin Instagram:...
# ...

# %%
list_medsos = [x for x in df['MedSos']]
list_line = []
list_line_akhir = []
list_ig = []
list_ig_akhir = []

# ngebagi line sama ig berdasarkan input yang bagus
for i in list_medsos:
    line = False
    ig = False
    lala = i.split()
    if not line and not ig:
        # ini ada-ada be ngasih 2 id line pake atau
        if 'atau' in lala:
            list_line.append(lala[1])
            list_ig.append(lala[5])
        else:
            for y in lala:
                if 'line.me' in y:
                    list_line.append(y)
                    line = True
                if 'instagram.com' in y:
                    list_ig.append(y)
                    ig = True
            if not line:
                list_line.append(None)
            if not ig:
                list_ig.append(None)

# benerin biar jadi instagram.com/...... aja
for kata in list_ig:
    if kata != None:
        if 'instagram:https://www.' in kata.lower():
            list_ig_akhir.append(kata[22:])
        elif 'instagram:https://' in kata.lower():
            list_ig_akhir.append(kata[18:])
        elif 'instagram:http://' in kata.lower():
            list_ig_akhir.append(kata[17:])
        elif 'instagram:' in kata.lower():
            list_ig_akhir.append(kata[10:])
        elif 'https://www.' in kata.lower():
            list_ig_akhir.append(kata[12:])
        elif 'https://' in kata.lower():
            list_ig_akhir.append(kata[8:])
        elif 'http://' in kata.lower():
            list_ig_akhir.append(kata[7:])
        elif 'www.' in kata.lower():
            list_ig_akhir.append(kata[4:])
        else:
            list_ig_akhir.append(kata)
    else:
        list_ig_akhir.append(None)

# benerin biar jadi line.me/..... aja
for kata in list_line:
    if kata != None:
        if 'line:https://' in kata.lower():
            list_line_akhir.append(kata[13:])
        elif ':https://' in kata.lower():
            list_line_akhir.append(kata[9:])
        elif 'https://' in kata.lower():
            list_line_akhir.append(kata[8:])
        elif 'http://' in kata.lower():
            list_line_akhir.append(kata[7:])
        else:
            list_line_akhir.append(kata)
    else:
            list_line_akhir.append(None)

# masukin line dari input gajelas
index = 0
for i in list_line_akhir:
    if i == None:
        if 'line' in list_medsos[index].lower():
            list_i = list_medsos[index].split()
            if list_i[1] == ':':
                try:
                    id_line = f'line.me/ti/p/{list_i[2]}'
                    list_line_akhir[index] = id_line
                except:
                    continue
            elif len(list_i) == 5:
                id_line = f'line.me/ti/p/{list_i[4]}'
                list_line_akhir[index] = id_line
            elif len(list_i) == 3:
                if "ig" in list_i[2]:
                    id_line = f'line.me/ti/p/{list_i[1]}'
                    list_line_akhir[index] = id_line
                else:
                    id_line = f'line.me/ti/p/{list_i[2]}'
                    list_line_akhir[index] = id_line
            elif len(list_i) == 2:
                id_line = f'line.me/ti/p/{list_i[0][5:]}'
                list_line_akhir[index] = id_line
            elif 'instagram' in list_i[1]:
                id_line = f'line.me/ti/p/{list_i[3]}'
                list_line_akhir[index] = id_line
            elif 'instagram' in list_i[0].lower():
                id_line = f'line.me/ti/p/{list_i[3]}'
                list_line_akhir[index] = id_line
            else:
                id_line = f'line.me/ti/p/{list_i[1]}'
                list_line_akhir[index] = id_line
    index += 1

# masukin ig dari input gajelas
id = 0
for i in list_ig_akhir:
    if i == None:
        if 'instagram' in list_medsos[id].lower():
            list_i = list_medsos[id].split()
            if len(list_i) == 6:
                link_ig = f'instagram.com/{list_i[5]}'
                list_ig_akhir[id] = link_ig
            elif len(list_i) == 5:
                link_ig = f'instagram.com/{list_i[4]}'
                list_ig_akhir[id] = link_ig
            elif len(list_i) == 4:
                if 'instagram' in list_i[0].lower():
                    if '@' in list_i[1]:
                        link_ig = f'instagram.com/{list_i[1][1:]}'
                        list_ig_akhir[id] = link_ig
                    elif '/' in list_i[3]:
                        splitan = list_i[1].split('/')
                        link_ig = f'instagram.com/{splitan[1]}'
                        list_ig_akhir[id] = link_ig
                    else:
                        link_ig = f'instagram.com/{list_i[1]}'
                        list_ig_akhir[id] = link_ig
                elif '/' in list_i[3]:
                    splitan = list_i[3].split('/')
                    link_ig = f'instagram.com/{splitan[1]}'
                    list_ig_akhir[id] = link_ig
                else:
                    link_ig = f'instagram.com/{list_i[3]}'
                    list_ig_akhir[id] = link_ig
            elif len(list_i) == 3:
                link_ig = f'instagram.com/{list_i[2]}'
                list_ig_akhir[id] = link_ig
            elif len(list_i) == 2:
                link_ig = f'instagram.com/{list_i[1][10:]}'
                list_ig_akhir[id] = link_ig
            else:
                if '/' in list_i[0]:
                    splitan = list_i[0].split('/')
                    link_ig = f'instagram.com/{splitan[1]}'
                    list_ig_akhir[id] = link_ig
        elif '@' in list_medsos[id].lower():
            link_ig = f'instagram.com/{list_medsos[id][1:]}'
            list_ig_akhir[id] = link_ig
        elif 'ig' in list_medsos[id].lower():
            splitan = list_medsos[id].split()
            link_ig = f'instagram.com/{splitan[2][3:]}'
            list_ig_akhir[id] = link_ig
    id += 1

# ngilangin , : di akhir kalo ada BAGIAN IG
index = 0
for i in list_ig_akhir:
    if i != None:
        if i.endswith(',') or i.endswith(':'):
            list_ig_akhir[index] = i[:-1]
    index += 1

# ngilangin , . : di akhir kalo ada BAGIAN LINE
index = 0
for i in list_line_akhir:
    if i != None:
        if i.endswith(',') or i.endswith('.') or i.endswith(':'):
            list_line_akhir[index] = i[:-1]
    index += 1



# ini buat ngecek aja
# id = 0
# for i in list_ig_akhir:
#     print(id, i)
#     print(id, list_medsos[id])
#     id += 1

# id = 0
# for i in list_line_akhir:
#     print(id, i)
#     print(id, list_medsos[id])
#     id += 1

# %%
# nambahin kolom Line sama Instagram
df['Line'] = list_line_akhir
df['Instagram'] = list_ig_akhir

# buat nampilin doang
df.head()
# df.info()
# Out:
#                 Nama Lengkap Nama Panggilan Tanggal Lahir  \
# 0  Muhammad Hilmy Abdul Aziz          Hilmy    30 09 2005
# 1             Soros Febriano          Soros    21 02 2004
# 2   Gyanamurti Adhikara Bano           Gyan     9 10 2003
# 3            Aaron Mario Lin          Aaron    29 03 2004
# 4      Adrial Natanael Liong         Adrial    15 09 2004
#
#                                          Foto (.jpg)  \
# 0  https://drive.google.com/open?id=1BmHDtiG2j-4Q...
# 1  https://drive.google.com/open?id=1P2oIp-DLe3tr...
# 2  https://drive.google.com/open?id=1lEFtpZUOTH91...
# 3  https://drive.google.com/open?id=1dmES9XX8qVh-...
# 4  https://drive.google.com/open?id=1sgZXjZqbWkC8...
#
#                                               MedSos  \
# 0  Line:  https://line.me/ti/p/eKSTrugSag Instagr...
# 1          https://www.instagram.com/soros_febriano/
# 2  Line: gyanbano09 Instagram: instagram.com/gyan...
# 3  Line: http://line.me/ti/p/aaronmlin Instagram:...
# ...

# %%
list_foto = [i for i in df["Foto (.jpg)"]]
list_foto_akhir = []

for i in list_foto:
    list_foto_akhir.append(i[i.find("?id=")+4:])

df["id foto"] = list_foto_akhir

df.head()
# Out:
#                 Nama Lengkap Nama Panggilan Tanggal Lahir  \
# 0  Muhammad Hilmy Abdul Aziz          Hilmy    30 09 2005
# 1             Soros Febriano          Soros    21 02 2004
# 2   Gyanamurti Adhikara Bano           Gyan     9 10 2003
# 3            Aaron Mario Lin          Aaron    29 03 2004
# 4      Adrial Natanael Liong         Adrial    15 09 2004
#
#                                          Foto (.jpg)  \
# 0  https://drive.google.com/open?id=1BmHDtiG2j-4Q...
# 1  https://drive.google.com/open?id=1P2oIp-DLe3tr...
# 2  https://drive.google.com/open?id=1lEFtpZUOTH91...
# 3  https://drive.google.com/open?id=1dmES9XX8qVh-...
# 4  https://drive.google.com/open?id=1sgZXjZqbWkC8...
#
#                                               MedSos  \
# 0  Line:  https://line.me/ti/p/eKSTrugSag Instagr...
# 1          https://www.instagram.com/soros_febriano/
# 2  Line: gyanbano09 Instagram: instagram.com/gyan...
# 3  Line: http://line.me/ti/p/aaronmlin Instagram:...
# ...

# %%
import cloudinary.api
import cloudinary.uploader
import cloudinary


cloudinary.config(
    cloud_name="djj4bzojc",
    api_key="618171932251618",
    api_secret="7uAztkbTzpFeRGgQUmCgtF3w0XY",
    secure=True
)

tt = df["Foto (.jpg)"][320:]

for i in tt:
    cloudinary.uploader.upload('https://drive.google.com/uc?export=view&id='+i[i.find("?id=")+4:],
                               public_id=i[i.find("?id=")+4:],
                               unique_filename=False
                               )
# Out:
# C:\Users\afati\AppData\Local\Temp\ipykernel_3388\1854864975.py:13: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   tt = df["Foto (.jpg)"][320:]

# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from apiclient import errors
from apiclient.http import MediaFileUpload

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/drive.metadata.readonly']


def main():
    """Shows basic usage of the Drive v3 API.
    Prints the names and ids of the first 10 files the user has access to.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    try:
        service = build('drive', 'v3', credentials=creds)
        tt = df["id foto"]
        list_nama_foto = []
        # Call the Drive v3 API
        for i in tt:
            file = service.files().get(fileId=i).execute()
            list_nama_foto.append(file['name'])
        df["nama foto"] = list_nama_foto
        df["nama foto"]
    except HttpError as error:
        # TODO(developer) - Handle errors from drive API.
        print(f'An error occurred: {error}')


main()

# %%
# df.to_csv('file_baru2.csv', index=False)
df.tail()
# Out:
#                      Nama Lengkap                 Nama Panggilan  \
# 58  Fariska Fedira Ardhanariswari                        Fariska
# 59          Melvara Zafirah Ramsi                           Elva
# 60           Eryanda Arian Ro'uuf  er eryan eryanda terserah dah
# 61   Muhammad Faishal Adly Nelwan                          Pesol
# 62               Chelsea Angelica                        Chelsea
#
#    Tanggal Lahir                                        Foto (.jpg)  \
# 58     3 03 2004  https://drive.google.com/open?id=1kA7uElC8y72y...
# 59    27 12 2003  https://drive.google.com/open?id=1PaVrQJel0sl6...
# 60    19 01 2004  https://drive.google.com/open?id=1ev8hJce0mQc7...
# 61    11 08 2004  https://drive.google.com/open?id=1w8W5Y0t2Z83Y...
# 62    28 11 2005  https://drive.google.com/open?id=11ZxCkWVxwRdw...
#
#                                                MedSos  \
# 58  Line: https://line.me/ti/p/SmwtStgw_0 Instagra...
# ...
